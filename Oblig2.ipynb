# %% [markdown]
# # DAT110 - Andre obligatoriske oppgave (2025)
# #### Konfidensintervaller, hypotesetesting og Goodness og Fit
# ### Format på besvarelsen:
#
# * __Kommentering:__ Filene skal inneholde tekst og kode (Oppgave 1c, 2a, 2b, 2c) som besvarer oppgavene, koden skal være godt kommentert.
# * __Samarbeid:__ Det er lov å samarbeide med én medstudent (maks 1) på oppgaven. Besvarelsen (som da merkes med begges navn) leveres ved å LASTE DEN OPP PÅ NAVNET TIL den dere har OPPFØRT FØRST. Den andre av partnerne laster kun opp en kort tekstfil som hevnviser til navnet på partneren som har lastet opp selve besvarelsen.
# * __Besvarelsen:__ Du/dere skal laste opp en `.zip` fil som inneholder svartekst og Julia-program.
# * __Opplastingen:__ Gjøres på Canvas via knappen `Lever Oppgave`
#
#
# * **OBS!** Husk å skrive tydelig navn øverst i filen(e)! For eksempel:
#
# ```julia
# # NB: Vi kan bruke "#" for å legge inn linjer med kommenterende tekst i Julia
# # ----------------------------------
# # Navn: Anna Armen & Geir-Arne Foten
# # ----------------------------------
# # ...
# #
# ```
#
# ### Innleveringsfrist:
#
# * 09.04.2025 - 23:59

# %% [markdown]
# ---
# ## Oppgave 1 - Populasjons- og utvalgsandeler i en undersøkelse av arbeidsledighet i arbeidsfør befolkning
#
# I et tilfeldig utvalg av 500 arbeidsføre personer, ble det funnet at 41 personer er arbeidsledige.
#
# **Informasjon for oppgavene 1a) og 1b) nedenfor**
# * _Utvalgsstørrelse:_ $n=500$
# * _Antall observerte arbeidsledige:_ $n_s = 41$
# * _Signifikansnivå:_ $\alpha = 0.05$
# * _Nullhypoteseandel:_ $p_0 = 0.055$
#
# **Oppgave 1a: Konfidensintervall**<br>
# a) Beregn et $100(1-\alpha)\%$ konfidensintervall for andelen arbeidsledige i den totale populasjonen av arbeidsføre personer, der $\alpha = 0.05$.
#
# Forklar hvilke antagelser du gjør ved
#    1. Beregning av standardfeilen (SE).
#    2. Valg av kritisk verdi og bestemmelse av feilmarginen (ME).
#
# **Oppgave 1b: Hypotesetesting**<br>
# b) Utfør en hypotesetest for å undersøke om andelen arbeidsledige i populasjonen er større enn $5.5\%$ (et tall som ble framlagt av arbeidsministeren i siste TV-debatt). Bruk signifikansnivå $\alpha = 0.05$.
#
# * Formuler nullhypotesen ($H_0$) og den alternative hypotesen ($H_1$).
# * Beregn testobservatoren og forklar hvilken testobservator du velger å bruke, og hvorfor.
# * Beregn $p$-verdien.
# * Trekk en konklusjon basert på resultatet av hypotesetesten.
#
# **Oppgave 1c: Julia-kode**<br>
# Lag godt kommentert Julia-kode som løser Oppgave 1a og 1b. (Du kan gjerne ta utgangspunkt i kode fra forelesningsnotatene.)

# %% [markdown]
# ---
# ## Oppgave 2 - Terningkast med mulig manipulert (hjemmelaget) terning
#
# Et terningkast resulterer som kjent i en av seks disjunkte begivenheter:<br>
# $A_1$ (hvis terningen viser en $1$-er), $A_2$ (hvis terningen viser en $2$-er), ..., $A_6$ (hvis terningen viser en $6$-er).
#
# Etter $n = 120$ terningkast med vår hjemmelagede terning har vi observert de ulike begivenhetene i følgende antall:
# - $A_1$: $12$ ganger,
# - $A_2$: $20$ ganger
# - $A_3$: $13$ ganger,
# - $A_4$: $27$ ganger
# - $A_5$: $25$ ganger,
# - $A_6$: $23$ ganger
#
# Definèr begivenhetene
# - $C=A_1\cup A_2$
# - $D=A_4\cup A_5$
#
# og la $p_C$ og $p_D$ betegne de sanne (men ukjente) sannsynlighetene for disse to begivenhetene.
#
# **Oppgave 2a):**<br>
# 1. Beskriv de to begivenhetene $C$ og $D$ med ord.
# 2. Foreslå empiriske estimater $\hat{p}_C$ og $\hat{p}_D$ for sannsynlighetene $p_C$  og $p_D$.
# 3. Velg $\alpha = 0.10$, og lag et $100(1-\alpha)\%$  konfidensintervall for $\hat{p}_C-\hat{p}_D$ basert på de $120$ terningskastene.
# 4. Test nullhypotesen om to andeler er like: $H_0: p_C = p_D$ versus $H_1: p_C \neq p_D$, beregn $p$-verdien og konkluder om vi kan forkaste $H_0$ ved et $5\%$ signifikansnivå.
# 5. Lag godt kommentert Julia-kode som løser punktene 1-4. (Du kan gjerne ta utgangspunkt i kode fra forelesningsnotatene.)
#
# __Oppgave 2b):__<br>
# Anta at de disjunkte begivenhetene $A_1,\ ...,\ A_6$ har like sannsynligheter $p_1=p_2 = \ ...\ =p_6 = \frac{1}{6}$.<br>
# 1. Forklar hvordan du kan teste (Goodness of Fit) $H_0: p_1=p_2 = \ ...\ =p_6 = \frac{1}{6}$ versus $H_1: p_i\neq p_j$ for minst et par ($i\neq j$) av sannsynligheter.
# 2. Angi de observerte ($O_i$) og forventede ($E_i$) frekvensene.
# 3. Beregn testobservatoren, antall frihetsgrader, bestem $p$-verdien for testen, og avgjør om $H_0$ forkastes på et $3\%$ signifikansnivå.
# 4. Lag godt kommentert Julia-kode som løser punkt 3. (Du kan gjerne ta utgangspunkt i kode fra forelesningsnotatene.)
#
# __Oppgave 2c):__<br>
# Definer begivenheten $E = A_2\cup A_6$.
# 1. Beskriv begivenheten $E$ med ord. <br>
# La $\#G$ betegne antall forekomster av en terningkast-begivenhet $G$ basert på utfallene av de $120$ terningkastene beskrevet innledningsvis, f. eks er $\#E = 20+23 = 43$:
# 2. Fyll inn korrekte tallverdier i tabellen basert på de $120$ observerte terningkastene<br>
#
# |                  | $$C$$        | $$C^c$$          | **Sum** |
# |:----------------:|-----------:|---------------:|-------:|
# | $E$              | $O_{11}=\#(E\cap C)$| $O_{12}=\#(E\cap C^0c)$  | $\#E$    |
# | $E^c$            | $O_{21}=\#(E^c\cap C)$| $O_{22}=\#(E^c\cap C^c)$| $\#E^c$     |
# | **Sum**          | $$\#C$$          | $$\#C^c$$      | $$n$$      |
#
# 3. Angi de tilhøende marginale sannsynlighetene som $(p_1, p_2)$ og $(q_1, q_2)$, og bestem verdien for disse basert på den innfylte tallene i tabellen.
# 4. Bestem alle de forventede frekvensene $E_{ij}$ under nullhypotestens ($H_0$) antagelsen om uavhengighet mellom de to marginalfordelingene, og gi en presis formulering av hypotesetesingsproblemet om uavhengige marginalfordelinger.
# 5. Bestem antall frihetsgrader, verdien på testobservatoren og på den resulterende $p$-verdien, og avgjør om $H_0$ forkastes på et $1\%$ signifikansnivå.
# 4. Lag godt kommentert Julia-kode som løser punkt 5. (Du kan gjerne ta utgangspunkt i kode fra forelesningsnotatene.)
#
# ---

# %% [markdown]
# __Husk:__<br>
# Gi gode kommentarer som forklarer hvordan koden i programmene dine virker.
#
# \
# \
# Lykke til!
